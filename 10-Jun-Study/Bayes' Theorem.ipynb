# %%
def bayes_test(p_disease,p_pos_given_disease, p_pos_given_healthy):
    p_healthy = 1- p_disease
    p_pos = (p_pos_given_disease * p_disease) + (p_pos_given_healthy * p_healthy)

    #bayes Theorem : P(A|B) = P(B|A) * P(A) / P(B)

    posterior = (p_pos_given_disease * p_disease) / p_pos
    return posterior
    print(f"Probabilty of actually having disease: {bayes_test(0.01,0.99,0.05):.4f}")

# %%
def bayes_test(p_disease, p_pos_given_disease, p_pos_given_healthy):
    # Total probability of testing positive (P(B))
    p_healthy = 1 - p_disease
    p_pos = (p_pos_given_disease * p_disease) + (p_pos_given_healthy * p_healthy)

    # Bayes Theorem: P(A|B) = P(B|A) * P(A) / P(B)
    posterior = (p_pos_given_disease * p_disease) / p_pos
    return posterior

print(f"Probability of actually having disease: {bayes_test(0.01, 0.99, 0.05):.4f}")
# Out:
# Probability of actually having disease: 0.1667

# %%
def bayes(prior, likelihood, evidence):
    return (likelihood * prior) / evidence

# Example A: Spam Filter
# Prior: 20% of all emails are spam
# Likelihood: P("Winner"|Spam) = 0.6, P("Winner"|Ham) = 0.05
p_spam = 0.20
p_ham = 0.80
p_winner_spam = 0.6
p_winner_ham = 0.05
p_winner = (p_winner_spam * p_spam) + (p_winner_ham * p_ham)

prob_spam_given_winner = bayes(p_spam, p_winner_spam, p_winner)
print(f"Prob of Spam given 'Winner': {prob_spam_given_winner:.4f}")
# Out:
# Prob of Spam given 'Winner': 0.7500

# %%
def bayes(prior, likelihood, evidence):
    return (likelihood * prior) / evidence

# Example A: Spam Filter
# Prior: 20% of all emails are spam
# Likelihood: P("Winner"|Spam) = 0.6, P("Winner"|Ham) = 0.05
p_spam = 0.20
p_ham = 0.80
p_winner_spam = 0.6
p_winner_ham = 0.05
p_winner = (p_winner_spam * p_spam) + (p_winner_ham * p_ham)

prob_spam_given_winner = bayes(p_spam, p_winner_spam, p_winner)
print(f"Prob of Spam given 'Winner': {prob_spam_given_winner:.6f}")
# Out:
# Prob of Spam given 'Winner': 0.750000

# %%
def bayes(prior, likelihood, evidence):
    return (likelihood * prior) / evidence

# Example A: Spam Filter
# Prior: 20% of all emails are spam
# Likelihood: P("Winner"|Spam) = 0.6, P("Winner"|Ham) = 0.05
p_spam = 0.20
p_ham = 0.80
p_winner_spam = 0.6
p_winner_ham = 0.09
p_winner = (p_winner_spam * p_spam) + (p_winner_ham * p_ham)

prob_spam_given_winner = bayes(p_spam, p_winner_spam, p_winner)
print(f"Prob of Spam given 'Winner': {prob_spam_given_winner:.5f}")
# Out:
# Prob of Spam given 'Winner': 0.62500
