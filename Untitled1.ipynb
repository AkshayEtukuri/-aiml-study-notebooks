# %%
import os
print("Jupyter is looking in this folder:")
print(os.getcwd())

print("\nThese are all the files Jupyter can see in that folder:")
import os
print(os.listdir())
# Out:
# Jupyter is looking in this folder:
# C:\Users\Admin\OneDrive\Desktop\-aiml-study-notebooks
#
# These are all the files Jupyter can see in that folder:
# ['.git', '.gitignore', '.ipynb_checkpoints', 'data.csv', 'Filling Area.ipynb', 'Matplotlib bar graph.ipynb', 'matplotlib.ipynb', 'piechart.ipynb', 'plot.png', 'Stackplots.ipynb', 'Untitled.ipynb', 'Untitled1.ipynb', 'Week1_Python', 'Week2_Math', 'Week3_CoreML']
